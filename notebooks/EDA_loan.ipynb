# %% [markdown]
# Performing EDA for Loan Approval Dataset

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('../datasets/loan_approval_dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Id   Income  Age  Experience Married/Single House_Ownership  \
# 0           0   1  1303834   23           3         single          rented
# 1           1   2  7574516   40          10         single          rented
# 2           2   3  3991815   66           4        married          rented
# 3           3   4  6256451   41           2         single          rented
# 4           4   5  5768871   47          11         single          rented
#
#   Car_Ownership           Profession                 CITY           STATE  \
# 0            no  Mechanical_engineer                 Rewa  Madhya_Pradesh
# 1            no   Software_Developer             Parbhani     Maharashtra
# 2            no     Technical_writer            Alappuzha          Kerala
# 3           yes   Software_Developer          Bhubaneswar          Odisha
# 4            no        Civil_servant  Tiruchirappalli[10]      Tamil_Nadu
#
#    CURRENT_JOB_YRS  CURRENT_HOUSE_YRS  Risk_Flag
# ...

# %%
df = df.drop(columns=['Unnamed: 0','Id'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252000 entries, 0 to 251999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Income             252000 non-null  int64
#  1   Age                252000 non-null  int64
#  2   Experience         252000 non-null  int64
#  3   Married/Single     252000 non-null  object
#  4   House_Ownership    252000 non-null  object
#  5   Car_Ownership      252000 non-null  object
#  6   Profession         252000 non-null  object
#  7   CITY               252000 non-null  object
#  8   STATE              252000 non-null  object
#  9   CURRENT_JOB_YRS    252000 non-null  int64
#  10  CURRENT_HOUSE_YRS  252000 non-null  int64
#  11  Risk_Flag          252000 non-null  int64
# dtypes: int64(6), object(6)
# memory usage: 23.1+ MB

# %%
df.shape
# Out:
# (252000, 12)

# %%
df.describe()
# Out:
#              Income            Age     Experience  CURRENT_JOB_YRS  \
# count  2.520000e+05  252000.000000  252000.000000    252000.000000
# mean   4.997117e+06      49.954071      10.084437         6.333877
# std    2.878311e+06      17.063855       6.002590         3.647053
# min    1.031000e+04      21.000000       0.000000         0.000000
# 25%    2.503015e+06      35.000000       5.000000         3.000000
# 50%    5.000694e+06      50.000000      10.000000         6.000000
# 75%    7.477502e+06      65.000000      15.000000         9.000000
# max    9.999938e+06      79.000000      20.000000        14.000000
#
#        CURRENT_HOUSE_YRS      Risk_Flag
# count      252000.000000  252000.000000
# mean           11.997794       0.123000
# std             1.399037       0.328438
# min            10.000000       0.000000
# 25%            11.000000       0.000000
# 50%            12.000000       0.000000
# 75%            13.000000       0.000000
# ...

# %%
df.columns
# Out:
# Index(['Income', 'Age', 'Experience', 'Married/Single', 'House_Ownership',
#        'Car_Ownership', 'Profession', 'CITY', 'STATE', 'CURRENT_JOB_YRS',
#        'CURRENT_HOUSE_YRS', 'Risk_Flag'],
#       dtype='object')

# %%
df.head()
# Out:
#     Income  Age  Experience Married/Single House_Ownership Car_Ownership  \
# 0  1303834   23           3         single          rented            no
# 1  7574516   40          10         single          rented            no
# 2  3991815   66           4        married          rented            no
# 3  6256451   41           2         single          rented           yes
# 4  5768871   47          11         single          rented            no
#
#             Profession                 CITY           STATE  CURRENT_JOB_YRS  \
# 0  Mechanical_engineer                 Rewa  Madhya_Pradesh                3
# 1   Software_Developer             Parbhani     Maharashtra                9
# 2     Technical_writer            Alappuzha          Kerala                4
# 3   Software_Developer          Bhubaneswar          Odisha                2
# 4        Civil_servant  Tiruchirappalli[10]      Tamil_Nadu                3
#
#    CURRENT_HOUSE_YRS  Risk_Flag
# ...

# %%
categorical_features = df.select_dtypes(include='object').columns
numerical_features = df.select_dtypes(exclude='object').columns

# %%
for feature in categorical_features:
    plt.figure(figsize=(4,3))
    plt.title(feature)
    sns.histplot(data=df,x=df[feature],hue='Risk_Flag',kde=True)
    plt.show()

# %%
df.columns
# Out:
# Index(['Income', 'Age', 'Experience', 'Married/Single', 'House_Ownership',
#        'Car_Ownership', 'Profession', 'CITY', 'STATE', 'CURRENT_JOB_YRS',
#        'CURRENT_HOUSE_YRS', 'Risk_Flag'],
#       dtype='object')

# %%
sns.histplot(data=df,x='Income',hue='Risk_Flag')
# Out:
# <Axes: xlabel='Income', ylabel='Count'>

# %% [markdown]
# ### insight: people with high income tends to get loan easily

# %%
sns.histplot(data=df,x='Age',hue='Risk_Flag')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['Income', 'Age', 'Experience', 'Married/Single', 'House_Ownership',
#        'Car_Ownership', 'Profession', 'CITY', 'STATE', 'CURRENT_JOB_YRS',
#        'CURRENT_HOUSE_YRS', 'Risk_Flag'],
#       dtype='object')

# %%
sns.barplot(data=df,x='Experience',hue='Risk_Flag')
# Out:
# <Axes: xlabel='Experience'>

# %% [markdown]
# ### insights people with high experience tends to have low risk to get the loan

# %%
df.columns
# Out:
# Index(['Income', 'Age', 'Experience', 'Married/Single', 'House_Ownership',
#        'Car_Ownership', 'Profession', 'CITY', 'STATE', 'CURRENT_JOB_YRS',
#        'CURRENT_HOUSE_YRS', 'Risk_Flag'],
#       dtype='object')

# %%
sns.histplot(data=df,x='Married/Single',hue='Risk_Flag')
# Out:
# <Axes: xlabel='Married/Single', ylabel='Count'>

# %% [markdown]
# ### ingle individuals might be more prone to financial or behavioral risks compared to married individuals.

# %%
df.columns
# Out:
# Index(['Income', 'Age', 'Experience', 'Married/Single', 'House_Ownership',
#        'Car_Ownership', 'Profession', 'CITY', 'STATE', 'CURRENT_JOB_YRS',
#        'CURRENT_HOUSE_YRS', 'Risk_Flag'],
#       dtype='object')

# %%
plt.subplot(1,2,1)
sns.histplot(data=df,x='House_Ownership',hue='Risk_Flag')
plt.subplot(1,2,2)
sns.histplot(data=df,x='Car_Ownership',hue='Risk_Flag')
# Out:
# <Axes: xlabel='Car_Ownership', ylabel='Count'>
